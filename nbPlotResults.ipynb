# %% [markdown]
# # Result Plots
#     refer PlotResultsV2.py
#     Created: 21st July 2025
#     Last modified: 20th Oct 2025

# %%
from Core.PlotsResultsV2 import CAnalyzeResults

# %% [markdown]
# ---
# # Select Dataset

# %% [markdown]
# ## <font color='red'>MNIST</font>

# %%
nEPOCHS = 100
strToken = '_Digit'
strDSResults = '../ALL_Results/Results25Aug23/Digit_2023-08-21_12_32_49'
strOutDir = '../ALL_Results/Results25Aug23/Digit_2023-08-21_12_32_49_results'
strTitle = 'Digit, Total: (1797, 64) Training: (539, 64)'

# %% [markdown]
# ## <font color='red'>Kyoto</font>

# %% [markdown]
# #### Original

# %%
strToken = '_Kyoto'
strDSResults = '../ALL_Results/Results25Aug23/Kyoto_2023-08-21_14_36_44'
strOutDir = '../ALL_Results/Results25Aug23/Kyoto_2023-08-21_14_36_44_results/'
strTitle = 'Kyoto, Total: (60000, 13) Training: (6000, 13)'

# %% [markdown]
# #### Synthetic Data
#     2025_07_22

# %%
strToken = '_KyotoSyn'
strDSResults = '../ALL_Results/Results10Aug25R1/KyotoSyn_2025_07_22'
strOutDir = '../ALL_Results/Results10Aug25R1/KyotoSyn_2025_07_22_results'
strTitle = 'Kyoto, Total: (63000, 13) Training: (6300, 13)'

# %% [markdown]
# #### With Adversarial data
#     2025_08_17

# %%
strToken = '_KyotoAdv'
strDSResults = '../ALL_Results/Results10Aug25R1/KyotoAdv_2025_08_17'
strOutDir = '../ALL_Results/Results10Aug25R1/KyotoAdv_2025_08_17_results'
strTitle = 'Kyoto, Total: (63000, 13) Training: (6300, 13)'

# %%
strDSResults = './local-data/Kyoto_2025_08_18_Shuffle' # 3
strOutDir = './local-data/Kyoto_2025_08_18_Shuffle_results'
strTitle = 'Kyoto, Total: (60000, 13) Training: (6000, 13)'
strToken = '_Kyoto'

# %% [markdown]
# #### 20/10/2025 with different C_D and C_A

# %%
strDSResults = './Results24Aug25R2/KyotoDiffC_2025_10_20'
strOutDir = './Results24Aug25R2/KyotoDiffC_2025_10_20_results'
strTitle = 'Kyoto, Total: (60000, 13) Training: (6000, 13)'

# %% [markdown]
# ## <font color='red'>Beth</font>

# %% [markdown]
# ### OoS

# %% [markdown]
#     First experiment Results25Aug23

# %%
strToken = '_Beth_OoS'
nSteps = 5
nEPOCHS = 10
strDSResults = '../ALL_Results/Results25Aug23/Beth_2023-08-23_11_37_54_OoS'
strOutDir = '../ALL_Results/Results25Aug23/Beth_2023-08-23_11_37_54_OoS_results'

# %% [markdown]
#     21st October 2025 with different models for D and A

# %%
strToken = '_Beth_OOS'
nEPOCHS = 10
nSteps = 5
strDSResults = '../ALL_Results/Results24Aug25R2/'
strOutDir = './ALL_Results/Results24Aug25R2/_results'
strTitle = 'Beth IS, Total: (xxx, 6) Training: (xxx, 6)'

# %% [markdown]
# ### IS

# %% [markdown]
#     2023-08-22

# %%
strToken = '_Beth_IS'
nEPOCHS = 10
nSteps = 5
strDSResults = '../ALL_Results/Results25Aug23/Beth_2023-08-22_14_50_55_IS'
strOutDir = '../ALL_Results/Results25Aug23/Beth_2023-08-22_14_50_55_IS_results'

# %% [markdown]
#     20th October 2025 with different models for D and A

# %%
strToken = '_Beth_IS'
nEPOCHS = 10
nSteps = 5
strDSResults = '../ALL_Results/Results24Aug25R2/Beth_IS_2025_10_20'
strOutDir = '../ALL_Results/Results24Aug25R2/Beth_IS_2025_10_20_results'
strTitle = 'Beth IS, Total: (1026970, 6) Training: (102697, 6)'

# %% [markdown]
# ### Beth60K

# %%
strToken = '_Beth60k'
nEPOCHS = 10
nSteps = 5
strDSResults = '../ALL_Results/Results24Aug25R2/Beth60K_2025_10_24'
strOutDir = '../ALL_Results/Results24Aug25R2/Beth60K_2025_10_24_results'
strTitle = 'Beth Adv, Total: (60000, 6) Training: (6000, 6)'

# %%
strToken = '_Beth60k_Syn'
nEPOCHS = 10
nSteps = 5
strDSResults = '../ALL_Results/Results24Aug25R2/Beth60K_Syn_2025_10_24'
strOutDir = '../ALL_Results/Results24Aug25R2/Beth60K_Syn_2025_10_24_results'
strTitle = 'Beth Syn, Total: (63000, 6) Training: (6300, 6)'

# %%
strToken = '_Beth60k_Adv'
nEPOCHS = 10
nSteps = 5
strDSResults = '../ALL_Results/Results24Aug25R2/Beth60K_Adv_2025_10_23'
strOutDir = '../ALL_Results/Results24Aug25R2/Beth60K_Adv_2025_10_23_results'
strTitle = 'Beth Adv, Total: (63000, 6) Training: (6300, 6)'

# %% [markdown]
# # Classifier selection

# %% [markdown]
# ##### Same C_D and C_A

# %%
nSteps = 5
nEPOCHS = 10
listDefClassifier = [3, 4, 5]
listAdvClassifier = [3, 4, 5]

# %% [markdown]
# ##### Different C_D and C_A

# %%
nSteps = 5
nEPOCHS = 10
listDefClassifier = [3, 0, 4]
listAdvClassifier = [2, 7, 5]

# %% [markdown]
# ---
# # Plot

# %%
obj = CAnalyzeResults()
obj.Plot_RTrain_Results(strTitle, strDSResults, strOutDir, strToken,
                        listDefClassifier, listAdvClassifier,
                        nSteps, nEPOCHS)
# Out:
# CAnalyzeResults Object Created
# ../ALL_Results/Results24Aug25R2/Beth60K_Syn_2025_10_24/A-3_Steps-5_Rep-10.csv
# ../ALL_Results/Results24Aug25R2/Beth60K_Syn_2025_10_24/A-4_Steps-5_Rep-10.csv
# ../ALL_Results/Results24Aug25R2/Beth60K_Syn_2025_10_24/A-5_Steps-5_Rep-10.csv
# ../ALL_Results/Results24Aug25R2/Beth60K_Syn_2025_10_24/D-3_A-3_Steps-5_Rep-10.csv
# ../ALL_Results/Results24Aug25R2/Beth60K_Syn_2025_10_24/D-3_A-4_Steps-5_Rep-10.csv
# ../ALL_Results/Results24Aug25R2/Beth60K_Syn_2025_10_24/D-3_A-5_Steps-5_Rep-10.csv
# ../ALL_Results/Results24Aug25R2/Beth60K_Syn_2025_10_24/D-4_A-3_Steps-5_Rep-10.csv
# ../ALL_Results/Results24Aug25R2/Beth60K_Syn_2025_10_24/D-4_A-4_Steps-5_Rep-10.csv
# ../ALL_Results/Results24Aug25R2/Beth60K_Syn_2025_10_24/D-4_A-5_Steps-5_Rep-10.csv
# ../ALL_Results/Results24Aug25R2/Beth60K_Syn_2025_10_24/D-5_A-3_Steps-5_Rep-10.csv
# ../ALL_Results/Results24Aug25R2/Beth60K_Syn_2025_10_24/D-5_A-4_Steps-5_Rep-10.csv
# ...
