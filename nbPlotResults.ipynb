# %% [markdown]
# # Result Plots
#     refer PlotResultsV2.py
#     Created: 21st July 2025
#     Last modified: 20th Oct 2025

# %%
from Core.PlotsResultsV2 import CAnalyzeResults

# %% [markdown]
# ---
# # Select Dataset

# %% [markdown]
# ## <font color='red'>MNIST</font>

# %%
nEPOCHS = 100
strToken = '_Digit'
strDSResults = '../Results25Aug23/Digit_2023-08-21_12_32_49'
strTitle = 'Digit, Total: (1797, 64) Training: (539, 64)'
# Out:
# ../Results25Aug/Digit_2023-08-21_12_32_49/A-3_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/A-4_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/A-5_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-3_A-3_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-3_A-4_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-3_A-5_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-4_A-3_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-4_A-4_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-4_A-5_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-5_A-3_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-5_A-4_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-5_A-5_Steps-5_Rep-100.csv
#
# AFR-AUC
#
# Combined: Mean of max afr for all rows:  0.85
# Matrix: Max afr for mean of matrix:  0.83
# Pin: Simple use of Random forest, pinning (max):  [0.78]
# RF: Simple use of Random forest for full trainset:  0.75
# TSet: Simple use of Random forest, avg:  0.75
# Post-learn: Max afr for post learning randomization:  0.57
#
# TPR
#
# Combined: Mean of max afr for all rows:  0.96
# Matrix: Max ROC-AUC for mean of matrix:  0.97
# Pin: Simple use of Random forest, pinning (max):  [0.95]  index  13
# RF: Simple use of Random forest for full trainset:  0.95
# TSet: Simple use of Random forest, avg:  0.92
# Post-learn: Max ROC-AUC for post learning randomization:  0.97

# %% [markdown]
# ## <font color='red'>Kyoto</font>

# %% [markdown]
# #### Original

# %%
strDSResults = '../Results25Aug23/Kyoto_2023-08-21_14_36_44'
strOutDir = './local-data/Results25Aug23_results/'
strTitle = 'Kyoto, Total: (60000, 13) Training: (6000, 13)'

# %% [markdown]
# #### Synthetic Data

# %%
strDSResults = './local-data/Kyoto_2025_07_22'
strOutDir = './local-data/Kyoto_2025_08_17_results'
strTitle = 'Kyoto, Total: (60000, 13) Training: (6000, 13)'

# %% [markdown]
# #### With Adversarial data

# %%
strDSResults = './local-data/Kyoto_2025_08_17'
strOutDir = './local-data/Kyoto_2025_08_17_results'
strTitle = 'Kyoto, Total: (60000, 13) Training: (6000, 13)'

# %%
strDSResults = './local-data/Kyoto_2025_08_18_Shuffle' # 3
strOutDir = './local-data/Kyoto_2025_08_18_Shuffle_results'
strTitle = 'Kyoto, Total: (60000, 13) Training: (6000, 13)'
strToken = '_Kyoto'

# %% [markdown]
# #### 20/10/2025 with different C_D and C_A

# %%
strDSResults = './local-data/Kyoto_2025_10_20'
strOutDir = './local-data/Kyoto_2025_10_20_results'
strTitle = 'Kyoto, Total: (60000, 13) Training: (6000, 13)'

# %% [markdown]
# ## <font color='red'>Beth</font>

# %% [markdown]
# ### OoS

# %%
strToken = '_Beth_OoS'
nSteps = 5
nEPOCHS = 10
strDSResults = '../Results25Aug23/Beth_2023-08-23_11_37_54_OoS'
strOutDir = '../Results25Aug23/Beth_2023-08-23_11_37_54_OoS_results'

# %% [markdown]
#     21st October 2025 with different models for D and A

# %%
strToken = '_Beth_OOS'
nEPOCHS = 10
nSteps = 5
strDSResults = './local-data/Beth_OOS_2025_10_21'
strOutDir = './local-data/Beth_OOS_2025_10_21_results'
strTitle = 'Beth IS, Total: (xxx, 6) Training: (xxx, 6)'

# %% [markdown]
# ### IS

# %%
strToken = '_Beth_IS'
nEPOCHS = 10
nSteps = 5
strDSResults = '../Results25Aug23/Beth_2023-08-22_14_50_55_IS'
strOutDir = '../Results25Aug23/Beth_2023-08-22_14_50_55_IS_results'

# %% [markdown]
#     20th October 2025 with different models for D and A

# %%
strToken = '_Beth_IS'
nEPOCHS = 10
nSteps = 5
strDSResults = './local-data/Beth_IS_2025_10_20'
strOutDir = './local-data/Beth_IS_2025_10_20_results'
strTitle = 'Beth IS, Total: (1026970, 6) Training: (102697, 6)'

# %% [markdown]
# ### Beth60K_Adv_2025_10_23

# %%
strToken = '_Beth60k_Adv'
nEPOCHS = 10
nSteps = 5
strDSResults = './local-data/Beth60K_Adv_2025_10_23'
strOutDir = './local-data/Beth60K_Adv_2025_10_23_results'
strTitle = 'Beth Adv, Total: (63000, 6) Training: (63000, 6)'

# %% [markdown]
# # Classifier selection

# %% [markdown]
# ##### Same C_D and C_A

# %%
nSteps = 5
nEPOCHS = 10
listDefClassifier = [3, 4, 5]
listAdvClassifier = [3, 4, 5]

# %% [markdown]
# ##### Different C_D and C_A

# %%
nSteps = 5
nEPOCHS = 10
listDefClassifier = [3, 0, 4]
listAdvClassifier = [2, 7, 5]

# %% [markdown]
# ---
# # Plot

# %%
obj = CAnalyzeResults()
obj.Plot_RTrain_Results(strTitle, strDSResults, strOutDir, strToken,
                        listDefClassifier, listAdvClassifier,
                        nSteps, nEPOCHS)
# Out:
# CAnalyzeResults Object Created
# ./local-data/Beth60K_Adv_2025_10_23/A-3_Steps-5_Rep-10.csv
# ./local-data/Beth60K_Adv_2025_10_23/A-4_Steps-5_Rep-10.csv
# ./local-data/Beth60K_Adv_2025_10_23/A-5_Steps-5_Rep-10.csv
# ./local-data/Beth60K_Adv_2025_10_23/D-3_A-3_Steps-5_Rep-10.csv
# ./local-data/Beth60K_Adv_2025_10_23/D-3_A-4_Steps-5_Rep-10.csv
# ./local-data/Beth60K_Adv_2025_10_23/D-3_A-5_Steps-5_Rep-10.csv
# ./local-data/Beth60K_Adv_2025_10_23/D-4_A-3_Steps-5_Rep-10.csv
# ./local-data/Beth60K_Adv_2025_10_23/D-4_A-4_Steps-5_Rep-10.csv
# ./local-data/Beth60K_Adv_2025_10_23/D-4_A-5_Steps-5_Rep-10.csv
# ./local-data/Beth60K_Adv_2025_10_23/D-5_A-3_Steps-5_Rep-10.csv
# ./local-data/Beth60K_Adv_2025_10_23/D-5_A-4_Steps-5_Rep-10.csv
# ./local-data/Beth60K_Adv_2025_10_23/D-5_A-5_Steps-5_Rep-10.csv
#
# AFR-AUC
#
# Combined: Mean of max afr for all rows:  0.69
# Matrix: Max afr for mean of matrix:  0.66
# Pin: Simple use of Random forest, pinning (max):  [0.62]
# RF: Simple use of Random forest for full trainset:  0.32
# TSet: Simple use of Random forest, avg:  0.41
# Post-learn: Max afr for post learning randomization:  0.57
#
# TPR
#
# Combined: Mean of max afr for all rows:  0.96
# Matrix: Max ROC-AUC for mean of matrix:  0.96
# Pin: Simple use of Random forest, pinning (max):  [0.96]  index  2
# RF: Simple use of Random forest for full trainset:  0.97
# TSet: Simple use of Random forest, avg:  0.97
# Post-learn: Max ROC-AUC for post learning randomization:  0.96
