# %% [markdown]
# # Result Plots
#     refer PlotResultsV2.py
#     Created: 21st July 2025

# %% [markdown]
# # Configure

# %%
from Core.PlotsResultsV2 import CAnalyzeResults

obj = CAnalyzeResults()
# Out:
# CAnalyzeResults Object Created

# %% [markdown]
# # MNIST

# %%
nRepeats = 100
strToken = '_Digit'
strDirPath = '../Results25Aug23/Digit_2023-08-21_12_32_49'
obj.Plot_RTrain_Results('Digit, Total: (1797, 64) Training: (539, 64)',
                        strDirPath, strOutDir, strToken, 
                        listSelectedClassifier, nSteps, nRepeats)
# Out:
# ../Results25Aug/Digit_2023-08-21_12_32_49/A-3_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/A-4_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/A-5_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-3_A-3_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-3_A-4_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-3_A-5_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-4_A-3_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-4_A-4_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-4_A-5_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-5_A-3_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-5_A-4_Steps-5_Rep-100.csv
# ../Results25Aug/Digit_2023-08-21_12_32_49/D-5_A-5_Steps-5_Rep-100.csv
#
# AFR-AUC
#
# Combined: Mean of max afr for all rows:  0.85
# Matrix: Max afr for mean of matrix:  0.83
# Pin: Simple use of Random forest, pinning (max):  [0.78]
# RF: Simple use of Random forest for full trainset:  0.75
# TSet: Simple use of Random forest, avg:  0.75
# Post-learn: Max afr for post learning randomization:  0.57
#
# TPR
#
# Combined: Mean of max afr for all rows:  0.96
# Matrix: Max ROC-AUC for mean of matrix:  0.97
# Pin: Simple use of Random forest, pinning (max):  [0.95]  index  13
# RF: Simple use of Random forest for full trainset:  0.95
# TSet: Simple use of Random forest, avg:  0.92
# Post-learn: Max ROC-AUC for post learning randomization:  0.97

# %% [markdown]
# # Kyoto

# %%
listDSResults = [
    '../Results25Aug23/Kyoto_2023-08-21_14_36_44',
    './local-data/Kyoto_2025_07_22',
    './local-data/Kyoto_2025_08_17',
]

listTitle = [
    'Kyoto, Total: (60000, 13) Training: (6000, 13)',
    'Kyoto, Total: (63000, 13) Training: (6300, 13)',
    'Kyoto, Total: (63000, 13) Training: (6300, 13)',
]

listOutDir = [
    './local-data/Results25Aug23_results/',
    './local-data/Kyoto_2025_07_22_results/',
    './local-data/Kyoto_2025_08_17_results',
]

nI = 2

strToken = '_Kyoto'
nRepeats = 10
nSteps = 5
listSelectedClassifier = [3, 4, 5]

obj.Plot_RTrain_Results(listTitle[nI],
                        listDSResults[nI], listOutDir[nI], strToken,
                        listSelectedClassifier, nSteps, nRepeats)
# Out:
# ./local-data/Kyoto_2025_08_17/A-3_Steps-5_Rep-10.csv
# ./local-data/Kyoto_2025_08_17/A-4_Steps-5_Rep-10.csv
# ./local-data/Kyoto_2025_08_17/A-5_Steps-5_Rep-10.csv
# ./local-data/Kyoto_2025_08_17/D-3_A-3_Steps-5_Rep-10.csv
# ./local-data/Kyoto_2025_08_17/D-3_A-4_Steps-5_Rep-10.csv
# ./local-data/Kyoto_2025_08_17/D-3_A-5_Steps-5_Rep-10.csv
# ./local-data/Kyoto_2025_08_17/D-4_A-3_Steps-5_Rep-10.csv
# ./local-data/Kyoto_2025_08_17/D-4_A-4_Steps-5_Rep-10.csv
# ./local-data/Kyoto_2025_08_17/D-4_A-5_Steps-5_Rep-10.csv
# ./local-data/Kyoto_2025_08_17/D-5_A-3_Steps-5_Rep-10.csv
# ./local-data/Kyoto_2025_08_17/D-5_A-4_Steps-5_Rep-10.csv
# ./local-data/Kyoto_2025_08_17/D-5_A-5_Steps-5_Rep-10.csv
#
# AFR-AUC
#
# Combined: Mean of max afr for all rows:  0.83
# Matrix: Max afr for mean of matrix:  0.81
# Pin: Simple use of Random forest, pinning (max):  [0.67]
# RF: Simple use of Random forest for full trainset:  0.51
# TSet: Simple use of Random forest, avg:  0.58
# Post-learn: Max afr for post learning randomization:  0.52
#
# TPR
#
# Combined: Mean of max afr for all rows:  0.9
# Matrix: Max ROC-AUC for mean of matrix:  0.94
# Pin: Simple use of Random forest, pinning (max):  [0.97]  index  1
# RF: Simple use of Random forest for full trainset:  0.98
# TSet: Simple use of Random forest, avg:  0.98
# Post-learn: Max ROC-AUC for post learning randomization:  0.93

# %% [markdown]
# # Beth_OoS

# %%
strToken = '_Beth_OoS'
nRepeats = 10
strDirPath = '../Results25Aug23/Beth_2023-08-23_11_37_54_OoS'
obj.Plot_RTrain_Results('Beth Total: (1026970, 6) Training: (856900, 6)',
                        strDirPath, strOutDir, strToken,
                        listSelectedClassifier, nSteps, nRepeats)
# Out:
# ../Results25Aug/Beth_2023-08-23_11_37_54_OoS/A-3_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-23_11_37_54_OoS/A-4_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-23_11_37_54_OoS/A-5_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-23_11_37_54_OoS/D-3_A-3_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-23_11_37_54_OoS/D-3_A-4_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-23_11_37_54_OoS/D-3_A-5_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-23_11_37_54_OoS/D-4_A-3_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-23_11_37_54_OoS/D-4_A-4_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-23_11_37_54_OoS/D-4_A-5_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-23_11_37_54_OoS/D-5_A-3_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-23_11_37_54_OoS/D-5_A-4_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-23_11_37_54_OoS/D-5_A-5_Steps-5_Rep-10.csv
#
# AFR-AUC
#
# Combined: Mean of max afr for all rows:  0.7
# Matrix: Max afr for mean of matrix:  0.67
# Pin: Simple use of Random forest, pinning (max):  [0.52]
# RF: Simple use of Random forest for full trainset:  0.4
# TSet: Simple use of Random forest, avg:  0.43
# Post-learn: Max afr for post learning randomization:  0.54
#
# TPR
#
# Combined: Mean of max afr for all rows:  0.71
# Matrix: Max ROC-AUC for mean of matrix:  0.73
# Pin: Simple use of Random forest, pinning (max):  [0.75]  index  4
# RF: Simple use of Random forest for full trainset:  0.75
# TSet: Simple use of Random forest, avg:  0.73
# Post-learn: Max ROC-AUC for post learning randomization:  0.72

# %% [markdown]
# # Beth_IS

# %%
strToken = '_Beth_IS'
nRepeats = 10
strDirPath = '../Results25Aug23/Beth_2023-08-22_14_50_55_IS'
obj.Plot_RTrain_Results('Beth Total: (1026970, 6) Training: (102697, 6)',
                        strDirPath, strOutDir, strToken,
                        listSelectedClassifier, nSteps, nRepeats)
# Out:
# ../Results25Aug/Beth_2023-08-22_14_50_55_IS/A-3_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-22_14_50_55_IS/A-4_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-22_14_50_55_IS/A-5_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-22_14_50_55_IS/D-3_A-3_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-22_14_50_55_IS/D-3_A-4_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-22_14_50_55_IS/D-3_A-5_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-22_14_50_55_IS/D-4_A-3_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-22_14_50_55_IS/D-4_A-4_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-22_14_50_55_IS/D-4_A-5_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-22_14_50_55_IS/D-5_A-3_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-22_14_50_55_IS/D-5_A-4_Steps-5_Rep-10.csv
# ../Results25Aug/Beth_2023-08-22_14_50_55_IS/D-5_A-5_Steps-5_Rep-10.csv
#
# AFR-AUC
#
# Combined: Mean of max afr for all rows:  0.67
# Matrix: Max afr for mean of matrix:  0.66
# Pin: Simple use of Random forest, pinning (max):  [0.54]
# RF: Simple use of Random forest for full trainset:  0.43
# TSet: Simple use of Random forest, avg:  0.41
# Post-learn: Max afr for post learning randomization:  0.58
#
# TPR
#
# Combined: Mean of max afr for all rows:  0.96
# Matrix: Max ROC-AUC for mean of matrix:  0.96
# Pin: Simple use of Random forest, pinning (max):  [0.97]  index  0
# RF: Simple use of Random forest for full trainset:  0.97
# TSet: Simple use of Random forest, avg:  0.97
# Post-learn: Max ROC-AUC for post learning randomization:  0.96
